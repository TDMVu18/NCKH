# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
import getpass
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import re

# %%
option = Options()
option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")
option.add_experimental_option(
    "prefs", {"profile.default_content_setting_values.notifications": 1}
)

# %%
PATH = "driver\chromedriver.exe"
driver = webdriver.Chrome(chrome_options=option, executable_path=PATH)
driver.get("https://www.facebook.com/")
driver.maximize_window()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_836/3864805029.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_options=option, executable_path=PATH)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_836/3864805029.py:2: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=option, executable_path=PATH)

# %%
user_name = driver.find_element(By.XPATH,"//input[@name='email']")
user_name.send_keys("yelan482@gmail.com")

# %%
password = driver.find_element(By.XPATH,"//input[@name='pass']")
password.send_keys('Linhcute542002')

# %% [markdown]
# close_login = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div[5]/div/div/div[1]/div/div[2]/div/div/div/div[1]")
# close_login.click()

# %% [markdown]
# log_in_button = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div[2]/div[2]/div[2]/div/form/div[2]/div[3]/div/div")
# log_in_button.click()

# %%
log_in_button = driver.find_element(By.XPATH,"//button[@type='submit']")
log_in_button.click()

# %%
driver.get('https://www.facebook.com/profile.php?id=100093944898219')
driver.maximize_window()

# %%
friendsTab = driver.find_element(By.XPATH,"//span[text()='Bạn bè']")
friendsTab.click()
sleep(3)

# %%
driver.execute_script("window.scrollTo(0, 500)")

# %%
def _get_friends_list():
    return driver.find_elements_by_css_selector(".x1iyjqo2.x1pi30zi [href]")
len(_get_friends_list())
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_836/3652086703.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   return driver.find_elements_by_css_selector(".x1iyjqo2.x1pi30zi [href]")
# 19

# %%
test_friend = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div[3]/div/div/div/div[1]/div[1]/div/div/div[4]/div/div/div/div/div/div/div/div/div[2]/div/div/div/div[2]/a[1]")

# %%
abc = str(test_friend.get_attribute("href"))
abc
# Out:
# 'https://www.facebook.com/profile.php?id=100093944898219&sk=friends_all'

# %%
match = re.search(r'friends_all$', abc)
if match is not None:
    print('Có hiện bạn')
else:
    print('Không hiện bạn')
# Out:
# Có hiện bạn

# %%
num_of_loaded_friends = len(_get_friends_list())
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    try:
        WebDriverWait(driver, 2).until(lambda driver: len(_get_friends_list()) > num_of_loaded_friends)
        num_of_loaded_friends = len(_get_friends_list())
    except TimeoutException:
        break  # no more friends loaded
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_836/3652086703.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   return driver.find_elements_by_css_selector(".x1iyjqo2.x1pi30zi [href]")

# %%
my_friend = driver.find_elements_by_css_selector(".x1iyjqo2.x1pi30zi [href]")
friendsList = []
urlList = []
for friend in my_friend:
    friendsList.append(friend.text)
    url = friend.get_attribute("href")
    urlList.append(url)
    print(friend.text, url)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_836/3020615203.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   my_friend = driver.find_elements_by_css_selector(".x1iyjqo2.x1pi30zi [href]")
#  https://www.facebook.com/photo/?fbid=117084638099699&set=a.117072028100960&__tn__=%3C
# 33 bạn bè https://www.facebook.com/profile.php?id=100093944898219&sk=friends
# Haan Nè https://www.facebook.com/profile.php?id=100093944898219
# Bún Đậu Mắm Tôm https://www.facebook.com/profile.php?id=100095318539348
# Nguyễn Phan Hải Hà https://www.facebook.com/profile.php?id=100093604746514
# Yun Chang https://www.facebook.com/profile.php?id=100093434710364
# Bui Nhu Yi https://www.facebook.com/profile.php?id=100093417395348
# Quốc Trung https://www.facebook.com/profile.php?id=100092725732662
# Nguyễn Hồng https://www.facebook.com/profile.php?id=100092291003966
# Ban KinhTe PG Huế https://www.facebook.com/profile.php?id=100090741570097
# Ng Trurz https://www.facebook.com/profile.php?id=100090594674851
# Lê Ngọc https://www.facebook.com/profile.php?id=100088807901230
# Bui Nhu Yi https://www.facebook.com/profile.php?id=100088129758744
# Lg Thao https://www.facebook.com/profile.php?id=100086154705517
# Catt Tuongg https://www.facebook.com/profile.php?id=100084533141879
# Nguyễn Dũng https://www.facebook.com/profile.php?id=100084280802756
# Nguyễn Nhật Linh https://www.facebook.com/profile.php?id=100083463199247
# Nguyệt Đảo Huỳnh https://www.facebook.com/profile.php?id=100081079387920
# Như Ý Bùi Thi https://www.facebook.com/profile.php?id=100075949454023
# Gia An https://www.facebook.com/profile.php?id=100074946630084
# Nhạt Phong https://www.facebook.com/profile.php?id=100073345831049
# Thanhh Phan https://www.facebook.com/profile.php?id=100071838585888
# Tr Tphuong https://www.facebook.com/profile.php?id=100071338903768
# Nguyễn Thị Ngọc Hân https://www.facebook.com/profile.php?id=100059850281510
# Kiều Oanh https://www.facebook.com/profile.php?id=100059578101517
# Ngô Thị Bích Ngọc https://www.facebook.com/profile.php?id=100058312930461
# Khánh Lynhh https://www.facebook.com/profile.php?id=100056140862803
# Nguyễn Ngọc Hiền https://www.facebook.com/profile.php?id=100044097634208
# Cháu Ten Nguyên https://www.facebook.com/chapnhan.sotiep
# Viên Lê Sinh https://www.facebook.com/vien.lesinh.3
# Nguyễn Thanh Trà My https://www.facebook.com/travainhoxanh
# Đặng Thúy https://www.facebook.com/dangthuy.8
# Quảng Hòa https://www.facebook.com/quang.hoa.127

# %%
len(urlList)
newfriend = friendsList[3:]
newfriend
newurl = urlList[3:]

# %%
len(friendsList)
friendsList
# Out:
# ['',
#  '344 bạn bè',
#  'Phuoc Nguyen',
#  'Thanh Hùng',
#  'Vũ Wibu',
#  'Toàn Hoàng',
#  'Nguyễn Phước',
#  'Huỳnh Dũng',
#  'Thùy Trang',
#  'Huỳnh Quốc Nam',
#  'Mai Nữ Phương Thảo',
#  'MY LINH',
#  'Huỳnh Hữu Nhật Minh',
#  'Như Quỳnh',
#  'Thu Trang',
#  'Tiên Lê',
#  'Đoàn Ngọc Tú Trinh',
#  'Lien Dang',
#  'Bảo Văn',
#  'Thanh Nhã',
#  'Cao Thị Thu Mai',
#  'Hiếu Võ',
#  'Nguyễn Thị Hồng Nhung',
#  'Nguyễn Thị Trà My',
#  'Trà My',
#  'Lê Thị Ngọc Thanh',
#  'Thanh Lụa',
#  'Liinh Nhii',
#  'Lê Thị Thuý Na',
#  'Hải Triều',
#  'Huỳnh Ngân',
#  'Trần Kim Yến',
#  'Phàm Negi',
#  'Hà Trang',
#  'Nguyễn Thắng',
#  'Jumun Mi',
#  'Mẫn Nghi',
#  'Duc Nguyen Thanh',
#  'Nguyễn Hoàng Thanh Thảo',
#  'Nguyễn Hoàng',
#  'Minh Tài',
#  'Trần Đình Sơn',
#  'Trần Huy',
#  'Nguyen Le Anh Tuan',
#  'Minh Phương',
#  'Hoài Linh',
#  'Thảo Hiếu',
#  'Nguyen Le Tuan Anh',
#  'Diệu Thi',
#  'Nguyễn H.Anh',
#  'Trần Thị Hòa',
#  'Võ Minh Nhật',
#  'Yuan Hau',
#  'Vy Oanh',
#  'Xuân Đỗ',
#  'Chính Nguyễn',
#  'Nguyễn Hiền',
#  'Tấn Mạnh',
#  'Bin Văn',
#  'Thảo Ngô',
#  'Tú Trương',
#  'Nguyễn Phan Bích Loan',
#  'Ty Ty Nguyễn',
#  'Huỳnh Thị Thu Hằng',
#  'Loan Pig',
#  'Kiều Diễm',
#  'Đoàn Đại Ngọc Phương',
#  'Tấn Tài',
#  'Lê Phương Trâm',
#  'Ngọc Ánh',
#  'Diệu Thu',
#  'Bảo Tâm',
#  'Nguyễn Như Phương',
#  'Hoàng Thị Phương Nhi',
#  'Chế Thị Hằng Nga',
#  'Thanh Nhàn',
#  'Guyn Huỳnh',
#  'Tiên Nguyễn',
#  'Lê Quang Trung',
#  'Lê Quang Nhật',
#  'Ngọc Duy',
#  'Trần Thị Ngọc Ánh',
#  'Nguyễn Tấn Tân',
#  'Đức Thịnh',
#  'Nguyễn Đức Mạnh',
#  'Hà Helly',
#  'Võ Tấn Nhật',
#  'Phạm Minh Quang',
#  'Phạm Phước Hoàng',
#  'Quan Nguyen',
#  'Như Linh',
#  'Lê Yến Nhi',
#  'Trần Lý Bửu',
#  'Phươngg Thảo',
#  'Kiều Loan',
#  'Nguyễn Ngọc Thảo',
#  'Yến Lê',
#  'Hữu Nhân',
#  'Huỳnh Dương Hoàng Long',
#  'Nhân Nguyễn',
#  'Trương Thị Khánh Nhung',
#  'Mina Ngo',
#  'Minh Đoàn',
#  'Bích Chi',
#  'Loan VT',
#  'Đăng Khải',
#  'Sử Thành Công',
#  'Anh Đức Nguyễn',
#  'Vân Phan',
#  'Hồng Ngát',
#  'Hương Ly',
#  'Quắn DeJong',
#  'Minh Huy Lê Bá',
#  'Mai Nhật Minh',
#  'Nguyen Le Anh Tuan',
#  'Bao Tran',
#  'Ty Ty',
#  'Phan Hùng Dương',
#  'Thanh Tú',
#  'Lê Phước Hoài',
#  'Như Quỳnh',
#  'Lê Thị Mỹ Duyên',
#  'Việt Trung',
#  'Văn Hiếu',
#  'Duy Hải',
#  'Phan Duy Minh Thắng',
#  'Wuỳnh Dũng',
#  'Liinh Nhii',
#  'Hưng Đinh',
#  'Valt Đặng',
#  'Tuann Anhh',
#  'Gia Bảo',
#  'Phong Nguyễn',
#  'Uy Phan',
#  'Lê Phước',
#  'Hữu Đạt',
#  'Minh Đoàn',
#  'Thu Hằng',
#  'Uyễn Nhi',
#  'Hoàng Lê',
#  'Oanh Hoàng',
#  'Yến Nhi',
#  'Trần Uyên',
#  'Mai Dương Quỳnh Anh',
#  'Huỳnh Ngân',
#  'Như Quỳnh',
#  'Mỹ Hạnh',
#  'Hữu Đạt',
#  'Phương Phương',
#  'Thùy Nhung Đoàn',
#  'Kim Chi',
#  'Thọ Nguyễn',
#  'Uyên Nhi',
#  'Minh Hiếu',
#  'Đức Huỳnh',
#  'Nguyen Phuong',
#  'Hoai Bui',
#  'Quang Nguyên',
#  'Hoài An',
#  'Tôn Nữ Thuỳ Linh',
#  'Nhân Tài',
#  'Nhỏ Nhỏ',
#  'Hồ Đình Nương',
#  'Hoàng Nữ Thu Phương',
#  'Thu Sương',
#  'Bích Vân',
#  'Lê Phước Hoàng',
#  'Vô Sắc',
#  'Thúy Vy',
#  'Hoàng Thủy',
#  'Nguyen Thi Van Nhi',
#  'Nguyễn Như Tuấn Đạt',
#  'Tuấn Phongg',
#  'Trần Văn Hiếuu',
#  'N. Hồng Nhung',
#  'Tuyền Ngô',
#  'Lê Nhật Phương',
#  'Tâm Trang',
#  'Bảo Trânn',
#  'Quang Nguyễn',
#  'Lê Văn Tân',
#  'Thanh Thủy',
#  'Hong Ngoc',
#  'Nguyễn Thanh Thảo',
#  'Văn Cường',
#  'Trung Võ',
#  'Hoàn Nguyễn',
#  'Diệu Hoàng',
#  'Kỳ Diệu Thi',
#  'Ngô Nhật Khánh',
#  'Phan Văn Duy Phúc',
#  'Van Anh',
#  'Phong Nguyễn',
#  'Duy Tân',
#  'Tú Đỗ',
#  'Minh Minh',
#  'Hoàng Minh',
#  'Bích Vân',
#  'Trần Nguyên Thiên Ý',
#  'Vầng Trương',
#  'Thùy Dung',
#  'Shii NT',
#  'Mây Trắng',
#  'Minh Anh Lê',
#  'Nguyễn Công Vinh',
#  'Nguyen Phuc The',
#  'Hoa Chỉ',
#  'Nguyễn Chính Hùng',
#  'Hồ Công',
#  'Hồ Văn Bửu',
#  'Phan Thế Đại Uy',
#  'Quang Namm',
#  'Hoàng Ngọc Quân',
#  'Phạm Văn Sỹ',
#  'Triệu',
#  'Nguyễn Tất Duy Thành',
#  'Thy Linh',
#  'Phạm Thị Khánh Linh',
#  'Lê Thị Bạch Tâm',
#  'Uyên Trần',
#  'Đạt Nguyễn',
#  'Phạm Thị Thanh Tâm',
#  'NK Thăng',
#  'Vân Lam Nguyễn',
#  'Trần Ngọc',
#  'Lý Bửu',
#  'Quốc Nam',
#  'Tâm Bình',
#  'Phúc Trâm',
#  'Nguyễn Hươn',
#  'Xuân Ngọc',
#  'Bui Ngoc',
#  'Nguyễn Văn Thông',
#  'Uyển Nhii',
#  'Hữu Đức',
#  'Đàm Lệ',
#  'Nguyễn Văn Him',
#  'Thùy Đoàn',
#  'Nhỏ Oliver',
#  'Nguyễn Thu',
#  'Hoàng Nữ Thu Phương',
#  'Dương Yến Hằng',
#  'Thắng Japani',
#  'Trần Thị Bảo Ngọc',
#  'Nguyễn Thị Yến Nhi',
#  'Hồ Bảo Ngọc',
#  'Tuấn Mai',
#  'Vi',
#  'Hà Giang',
#  'Thu Hà',
#  'Dương Quỳnh Châu',
#  'Tân Văn Võ',
#  'Nguyễn Văn Mẫn',
#  'Thanh Thanh',
#  'Trần Phạm Thùy Dương',
#  'Nguyễn Đỗ Nguyên Đô',
#  'Lê Huấn',
#  'Nguyễn Quế Trâm',
#  'Nguyen Van Khai',
#  'Hứa Ly',
#  'Quỳnh Như',
#  'Phan Duy Minh Thang',
#  'Sáng Trần',
#  'Đạt Thành',
#  'Nguyễn Thị Thùy Linh',
#  'Hoàng Oanh',
#  'Nguyễn Yến Nhi',
#  'Minhh Nhàng',
#  'Galvin Bách',
#  'Tây Nguyễn',
#  'Phát Trương',
#  'Nhu Quynh',
#  'Phạm Thị Lê Na',
#  'Hồ Đình Nương',
#  'Trần Quốc Hùng',
#  'Ngọc Thắm',
#  'Thuỳ Duyên',
#  'Thanh Lâm Nguyễn',
#  'Tôn Nữ Diễm Quỳnh',
#  'Tuyền Ngô',
#  'Hữuu Đạtt',
#  'Đặng Quỳnh',
#  'Tân Sama',
#  'Dan Doan',
#  'Phương Linh Hà',
#  'Huỳnh Khánh',
#  'Quỳnh Lưu',
#  'Thanh Thủy',
#  'Linh Huyền Nhung',
#  'Trà My',
#  'Minh Trí Hồ',
#  'Nguyễn Thị Thu Hương',
#  'Nguyễn Lệ',
#  'Sumika Saitoh',
#  'Lê Đức Long',
#  'Hà Giang',
#  'Tiểuu Ngânn',
#  'Hiệp Nguyễn',
#  'Diễm Trân',
#  'Phan Nguyễn Anh Đức',
#  'Uyên Hồ',
#  'Hồ Khắc Minh Huy',
#  'Phạm Quốc Đạt',
#  'Quốcc Dương',
#  'Kỳ Trương Kiều Nga',
#  'Thảo Vy',
#  'Khoa Đăng',
#  'Đỏ',
#  'Điểm Đoàn',
#  'Võ Bùi Hồng Phúc',
#  'Hồ Toàn',
#  'Chau Phan',
#  'Lê Thị Thu Hà',
#  'My Nguyễn',
#  'Trần Ngọc',
#  'Thanh Ngân',
#  'Quỳnh Như',
#  'Hoài Lý',
#  'Hồ Thị Ngọc Phước',
#  'Dương Thục Nhii',
#  'An Hoàng',
#  'Nhật Minh',
#  'Tom Tran']

# %%
import pandas as pd
df = pd.DataFrame(list(zip(newfriend, newurl)),
               columns =['Name', 'url'])
df
# Out:
#                    Name                                                url
# 0       Bún Đậu Mắm Tôm  https://www.facebook.com/profile.php?id=100095...
# 1    Nguyễn Phan Hải Hà  https://www.facebook.com/profile.php?id=100093...
# 2             Yun Chang  https://www.facebook.com/profile.php?id=100093...
# 3            Bui Nhu Yi  https://www.facebook.com/profile.php?id=100093...
# 4            Quốc Trung  https://www.facebook.com/profile.php?id=100092...
# 5           Nguyễn Hồng  https://www.facebook.com/profile.php?id=100092...
# 6     Ban KinhTe PG Huế  https://www.facebook.com/profile.php?id=100090...
# 7              Ng Trurz  https://www.facebook.com/profile.php?id=100090...
# 8               Lê Ngọc  https://www.facebook.com/profile.php?id=100088...
# 9            Bui Nhu Yi  https://www.facebook.com/profile.php?id=100088...
# 10              Lg Thao  https://www.facebook.com/profile.php?id=100086...
# 11          Catt Tuongg  https://www.facebook.com/profile.php?id=100084...
# 12          Nguyễn Dũng  https://www.facebook.com/profile.php?id=100084...
# 13     Nguyễn Nhật Linh  https://www.facebook.com/profile.php?id=100083...
# 14     Nguyệt Đảo Huỳnh  https://www.facebook.com/profile.php?id=100081...
# 15        Như Ý Bùi Thi  https://www.facebook.com/profile.php?id=100075...
# 16               Gia An  https://www.facebook.com/profile.php?id=100074...
# 17           Nhạt Phong  https://www.facebook.com/profile.php?id=100073...
# 18          Thanhh Phan  https://www.facebook.com/profile.php?id=100071...
# 19           Tr Tphuong  https://www.facebook.com/profile.php?id=100071...
# 20  Nguyễn Thị Ngọc Hân  https://www.facebook.com/profile.php?id=100059...
# 21            Kiều Oanh  https://www.facebook.com/profile.php?id=100059...
# 22    Ngô Thị Bích Ngọc  https://www.facebook.com/profile.php?id=100058...
# 23          Khánh Lynhh  https://www.facebook.com/profile.php?id=100056...
# 24     Nguyễn Ngọc Hiền  https://www.facebook.com/profile.php?id=100044...
# 25      Cháu Ten Nguyên           https://www.facebook.com/chapnhan.sotiep
# 26         Viên Lê Sinh             https://www.facebook.com/vien.lesinh.3
# 27  Nguyễn Thanh Trà My             https://www.facebook.com/travainhoxanh
# 28            Đặng Thúy                https://www.facebook.com/dangthuy.8
# 29            Quảng Hòa             https://www.facebook.com/quang.hoa.127

# %%
df
# Out:
#                  names
# 0
# 1           344 bạn bè
# 2         Phuoc Nguyen
# 3           Thanh Hùng
# 4              Vũ Wibu
# ..                 ...
# 318  Hồ Thị Ngọc Phước
# 319    Dương Thục Nhii
# 320           An Hoàng
# 321          Nhật Minh
# 322           Tom Tran
#
# [323 rows x 1 columns]

# %%
df_new = df['names'].str.split("\n", expand=True)

# %%
df_new
# Out:
#                         0                                                  1
# 0             Minh Anh Lê                     Tình nguyện viên tại Khát Vọng
# 1            Nguyễn Thắng                        Làm việc tại NYX Basketball
# 2               Hữuu Đạtt                                                Huế
# 3                  Đàm Lệ  Marketing tại Youth+ - Định hướng, đảm bảo việ...
# 4             Kỳ Diệu Thi                           THPT Chuyên Quốc Học Huế
# ..                    ...                                                ...
# 312            Thanh Nhàn                              Đại Học Ngoại Ngữ Huế
# 313              Thu Hằng                  Làm việc tại VietSeeds Foundation
# 314          Phong Nguyễn                                       Boss tại Huế
# 315  Nguyễn Thị Thùy Linh                                               None
# 316              Diệu Thi                    Trường THPT Phan Đăng Lưu - Huế
#
# [317 rows x 2 columns]
