# %%
# !pip install -r requirements.txt
# Out:
# Collecting selenium==4.18.1 (from -r requirements.txt (line 1))
#   Downloading selenium-4.18.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting pandas (from -r requirements.txt (line 2))
#   Downloading pandas-2.2.1-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\lenovo\miniconda3\envs\fb_crawl\lib\site-packages (from selenium==4.18.1->-r requirements.txt (line 1)) (4.10.0)
# Collecting numpy<2,>=1.22.4 (from pandas->-r requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\miniconda3\envs\fb_crawl\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 2))
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 2))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\miniconda3\envs\fb_crawl\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.16.0)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting idna (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting outcome (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading cffi-1.16.0-cp39-cp39-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: exceptiongroup in c:\users\lenovo\miniconda3\envs\fb_crawl\lib\site-packages (from trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1)) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.18.1->-r requirements.txt (line 1))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.0 MB 4.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.0 MB 4.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.0 MB 5.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/10.0 MB 5.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/10.0 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/10.0 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/10.0 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.0/10.0 MB 5.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.3/10.0 MB 5.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.0 MB 5.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.8/10.0 MB 5.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.0 MB 5.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.0 MB 5.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/10.0 MB 5.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.0 MB 5.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 5.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/10.0 MB 5.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/10.0 MB 5.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/10.0 MB 5.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.3/10.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/10.0 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/10.0 MB 5.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.1/10.0 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 6.4/10.0 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 6.7/10.0 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.0/10.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.2/10.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.5/10.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.8/10.0 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.0/10.0 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/10.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.6/10.0 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 5.8 MB/s eta 0:00:00
# Downloading pandas-2.2.1-cp39-cp39-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 6.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.5/11.6 MB 6.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.6 MB 6.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.6 MB 5.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11
MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.8 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 10.7/15.8 MB 5.8 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.8 MB 5.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.6/15.8 MB 5.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/15.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 12.4/15.8 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.7/15.8 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 13.0/15.8 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 13.2/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.5/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.8/15.8 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.0/15.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/15.8 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.8 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 15.4/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 5.6 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------- ------------------ 276.5/505.5 kB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  501.8/505.5 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 5.3 MB/s eta 0:00:00
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ---------------------------------------- 0.0/460.2 kB ? eta -:--:--
#    ---------------------- ----------------- 256.0/460.2 kB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  450.6/460.2 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  450.6/460.2 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  450.6/460.2 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 460.2/460.2 kB 2.4 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/345.4 kB 991.0 kB/s eta 0:00:01
#    --------------------------- ------------ 235.5/345.4 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 3.1 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ------------------------------------- -- 112.6/121.1 kB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 112.6/121.1 kB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 112.6/121.1 kB 6.4 MB/s eta 0:00:01
#    -------------------------------------- 121.1/121.1 kB 786.0 kB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/60.8 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 404.1 kB/s eta 0:00:00
# Downloading cffi-1.16.0-cp39-cp39-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#    ------------------------------- -------- 143.4/181.6 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 181.6/181.6 kB 3.6 MB/s eta 0:00:00
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB 3.4 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#    ---------------------------------------- 118.7/118.7 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: sortedcontainers, pytz, urllib3, tzdata, sniffio, pysocks, pycparser, numpy, idna, h11, certifi, attrs, wsproto, pandas, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-23.2.0 certifi-2024.2.2 cffi-1.16.0 h11-0.14.0 idna-3.6 numpy-1.26.4 outcome-1.3.0.post0 pandas-2.2.1 pycparser-2.21 pysocks-1.7.1 pytz-2024.1 selenium-4.18.1 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 tzdata-2024.1 urllib3-2.2.1 wsproto-1.2.0

# %%
# !conda env export > env.yaml

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
import getpass
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import re

# %%
option = Options()
option.add_argument("--disable-infobars")
option.add_argument("start-maximized")
option.add_argument("--disable-extensions")
option.add_experimental_option(
    "prefs", {"profile.default_content_setting_values.notifications": 1}
)

# %%
PATH = "chromedriver.exe"
driver = webdriver.Chrome(options=option)
driver.get("https://www.facebook.com/")
driver.maximize_window()

# %%
# Login
user_name = driver.find_element(By.XPATH,"//input[@name='email']")
user_name.send_keys("yelan482@gmail.com")
password = driver.find_element(By.XPATH,"//input[@name='pass']")
password.send_keys('Linhcute542002')

log_in_button = driver.find_element(By.XPATH,"//button[@type='submit']")
log_in_button.click()

# %%
driver.get('https://www.facebook.com/profile.php?id=100093944898219')

# %%
friendsTab = driver.find_element(By.XPATH,"//span[text()='Bạn bè']")
friendsTab.click()

# %%
driver.execute_script("window.scrollTo(0, 500)")

# %%
def _get_friends_list():
    return driver.find_elements(By.CSS_SELECTOR, ".x1iyjqo2.x1pi30zi [href]")
len(_get_friends_list())
# Out:
# 24

# %%
### Check lại cách load bạn bè

num_of_loaded_friends = len(_get_friends_list())
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    try:
        WebDriverWait(driver, 2).until(lambda driver: len(_get_friends_list()) > num_of_loaded_friends)
        num_of_loaded_friends = len(_get_friends_list())
        print(num_of_loaded_friends)
    except TimeoutException:
        break  # no more friends loaded

# %%
num_of_loaded_friends
# Out:
# 33

# %%
newfriend = [i.text for i in _get_friends_list()[1:]]
newurl = [i.get_attribute("href") for i in _get_friends_list()[1:]]

# %%
import pandas as pd
df = pd.DataFrame(list(zip(newfriend, newurl)),
               columns =['Name', 'url'])
df
# Out:
#                    Name                                                url
# 0            Ngocc Hann  https://www.facebook.com/profile.php?id=100093...
# 1          Nguyynn Haan  https://www.facebook.com/profile.php?id=100081...
# 2               Lê Ngọc  https://www.facebook.com/profile.php?id=100088...
# 3           Catt Tuongg  https://www.facebook.com/profile.php?id=100084...
# 4   Nguyễn Thị Ngọc Hân  https://www.facebook.com/profile.php?id=100059...
# 5            Bui Nhu Yi  https://www.facebook.com/profile.php?id=100088...
# 6          Viên Lê Sinh             https://www.facebook.com/vien.lesinh.3
# 7            Tr Tphuong  https://www.facebook.com/profile.php?id=100071...
# 8               Han Bow  https://www.facebook.com/profile.php?id=100095...
# 9             Bích Ngọc  https://www.facebook.com/profile.php?id=100058...
# 10              Lg Thao  https://www.facebook.com/profile.php?id=100086...
# 11    Phung Thi Nguyenn           https://www.facebook.com/chapnhan.sotiep
# 12           Hoài Thanh  https://www.facebook.com/profile.php?id=100094...
# 13   Nguyễn Phan Hải Hà  https://www.facebook.com/profile.php?id=100093...
# 14            Yun Chang  https://www.facebook.com/profile.php?id=100093...
# 15              Chí Bảo  https://www.facebook.com/profile.php?id=100092...
# 16          Nguyễn Hồng  https://www.facebook.com/profile.php?id=100092...
# 17    Ban KinhTe PG Huế  https://www.facebook.com/profile.php?id=100090...
# 18          Thanh Trucc            https://www.facebook.com/thanhtruc22023
# 19          Nguyễn Dũng  https://www.facebook.com/profile.php?id=100084...
# 20     Nguyễn Nhật Linh  https://www.facebook.com/profile.php?id=100083...
# 21           Phuong Lam  https://www.facebook.com/profile.php?id=100079...
# 22          Lưu Vanpelé  https://www.facebook.com/profile.php?id=100074...
# 23           Nhạt Phong  https://www.facebook.com/profile.php?id=100073...
# 24          Thanhh Phan  https://www.facebook.com/profile.php?id=100071...
# 25             Yew Nắng  https://www.facebook.com/profile.php?id=100065...
# 26          Khánh Lynhh               https://www.facebook.com/Lynhhchuche
# 27     Nguyễn Ngọc Hiền  https://www.facebook.com/profile.php?id=100044...
# 28           Bao Anh Lê         https://www.facebook.com/baoanh.le.3939503
# 29            Thanh Nga              https://www.facebook.com/thanhnga.240
# 30  Nguyễn Lê Trúc Bình  https://www.facebook.com/profile.php?id=615553...
# 31         Chinhh Ngocc  https://www.facebook.com/profile.php?id=615542...

# %% [markdown]
# # Infor

# %%
def get_name(url):
    url = url
    driver.get(url)
    driver.maximize_window()
    # name = driver.find_element(By.XPATH, '//h1[@class = "x1heor9g x1qlqyl8 x1pd3egz x1a2a7pz"]').text
    name = WebDriverWait(driver, 2).until(
        EC.presence_of_element_located((By.XPATH, '//h1[@class = "x1heor9g x1qlqyl8 x1pd3egz x1a2a7pz"]'))
    ).text
    return name

def get_about_place(url):
    url = url + '/about_places'    
    driver.get(url)
    driver.maximize_window()
    # place = driver.find_element(By.XPATH, "//span[@class = 'xt0psk2']").text
    place = WebDriverWait(driver, 2).until(
        EC.presence_of_element_located((By.XPATH, "//span[@class = 'xt0psk2']"))
    ).text
    return place

def get_gender(url):
    url = url + '/about_contact_and_basic_info'
    driver.get(url)
    driver.maximize_window()
    try:
        # /div[3]/div/div[2]/div/div/div[2]/div/div/div/div/div[1]/span
        # xyamay9 xqmdsaz x1gan7if x1swvt13 div[2]/div/div[1]/div/div/div[1]/div/div/
        # gender = driver.find_element(By.XPATH, "//div[@class='x1hq5gj4']/div/div/div[2]/div/div/div/div/div/span").text
        gender = WebDriverWait(driver, 2).until(
            EC.presence_of_element_located((By.XPATH, "//div[@class='xyamay9 xqmdsaz x1gan7if x1swvt13']/div[3]/div/div[2]/div/div/div[2]/div/div/div/div/div[1]/span"))
        ).text
    except:
        gender = None
    return gender

def get_date_of_birth(url):
    url = url + '/about_contact_and_basic_info'
    driver.get(url)
    driver.maximize_window()
    try:
        # date_month = driver.find_element(By.XPATH, "//div[@class = 'x1hq5gj4']/../div[3]/div/div/div[2]/div/div/div/div/div/span").text
        date_month = WebDriverWait(driver, 2).until(
            EC.presence_of_element_located((By.XPATH, "//div[@class = 'x1hq5gj4']/../div[3]/div/div/div[2]/div/div/div/div/div/span"))
        ).text
        year = WebDriverWait(driver, 2).until(
            EC.presence_of_element_located((By.XPATH, "//div[@class = 'x1hq5gj4']/../div[3]/div/div/div[2]/div[2]/div/div/div/div/span"))
        ).text
    except:
        date_month = None
        year = None
    return date_month, year

url = "https://www.facebook.com/ngphuoctthue"

name = get_name(url)
place = get_about_place(url)
gender = get_gender(url)
date_of_birth = get_date_of_birth(url)[0]
year = get_date_of_birth(url)[1]
print(name)
print(place)
print(gender)
print(date_of_birth)
print(year)

data = [
    {'name': name, 'place': place, 'gender': gender, 'date_of_birth': date_of_birth, 'year': year}
]

# %%
class UserInfor():
    def self.__init__():
        self.url = URL
        self.name = name
        
    def _get_name():
        pass

    def _get_gender():
        pass

    def _get_friend():
        pass

    def _get_date_of_birth():
        self.year = year 
        pass

# %%
df_new
# Out:
#                         0                                                  1
# 0             Minh Anh Lê                     Tình nguyện viên tại Khát Vọng
# 1            Nguyễn Thắng                        Làm việc tại NYX Basketball
# 2               Hữuu Đạtt                                                Huế
# 3                  Đàm Lệ  Marketing tại Youth+ - Định hướng, đảm bảo việ...
# 4             Kỳ Diệu Thi                           THPT Chuyên Quốc Học Huế
# ..                    ...                                                ...
# 312            Thanh Nhàn                              Đại Học Ngoại Ngữ Huế
# 313              Thu Hằng                  Làm việc tại VietSeeds Foundation
# 314          Phong Nguyễn                                       Boss tại Huế
# 315  Nguyễn Thị Thùy Linh                                               None
# 316              Diệu Thi                    Trường THPT Phan Đăng Lưu - Huế
#
# [317 rows x 2 columns]
